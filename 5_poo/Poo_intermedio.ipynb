# %% [markdown]
# # PPO Intermedio

# %% [markdown]
# Este reto plantea la creación de un flujo de trabajo completo para manejar datos de empleados mediante la implementación de tres clases distintas. El objetivo consiste en separar las responsabilidades de validación de datos, análisis estadístico y generación de reportes.

# %% [markdown]
# Se requiere contar con una lista de diccionarios llamada `empleados`, donde cada diccionario represente a un empleado con las siguientes claves obligatorias:

# %%
empleado = {
    "id": str,                    # Identificador único del empleado (UUID)
    "nombre": str,                # Nombre completo del empleado
    "edad": int,                  # Edad del empleado
    "genero": str,                # Género (Masculino, Femenino, etc.)
    "departamento": str,          # Departamento al que pertenece
    "cargo": str,                 # Cargo que desempeña en la empresa
    "email": str,                 # Correo electrónico
    "telefono": str,              # Número de teléfono
    "direccion": str,             # Dirección física
    "salario": float,             # Salario base anual (o mensual, según convenga)
    "fecha_contratacion": str,    # Fecha de contratación en formato YYYY-MM-DD
    "desempeno": float,           # Valor numérico que represente el desempeño (ej. 0 a 10)
    "activo": bool                # Indica si el empleado sigue activo en la empresa
}

# %%
import json
import re
import datetime
from fpdf import FPDF
import logging

# %%
class Logger:
    def __init__(self, log_file="app.log"):
        # Crear logger
        self.logger = logging.getLogger("App_Logger")
        self.logger.setLevel(logging.DEBUG)

        # Evitar duplicación de handlers
        if not self.logger.handlers:
            # Formato del log
            formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

            # Crear manejador para archivo
            file_handler = logging.FileHandler(log_file, encoding = "utf-8")
            file_handler.setFormatter(formatter)
            file_handler.setLevel(logging.DEBUG)

            # Crear manejador para imprimir consola
            console_handler = logging.StreamHandler()
            console_handler.setFormatter(formatter)
            console_handler.setLevel(logging.INFO)

            # Agregar handlers al logger
            self.logger.addHandler(file_handler)
            self.logger.addHandler(console_handler)

    def get_logger(self):
        return self.logger

# %%
class ReadData:
    def __init__(self, filename, logger):
        self.filename = filename
        self.logger = logger
        
    def read_json(self):
        #leer el archivo json de manera correcta
        with open(self.filename, "r", encoding="utf-8") as f:
            employees = [json.loads(line) for line in f] 
            self.logger.info(f"Datos obtenidos de {self.filename}")
        return employees

# %%
class EmployeeDataLoader:
    def __init__(self, employees, logger):
        self.employees = employees
        self.logger = logger
        
    def get_clean_data(self):
                
        mandatory_keys = {
            "id": str,                    # Identificador único del empleado (UUID)
            "nombre": str,                # Nombre completo del empleado
            "edad": int,                  # Edad del empleado
            "genero": str,                # Género (Masculino, Femenino, etc.)
            "departamento": str,          # Departamento al que pertenece
            "cargo": str,                 # Cargo que desempeña en la empresa
            "email": str,                 # Correo electrónico
            "telefono": str,              # Número de teléfono
            "direccion": str,             # Dirección física
            "salario": float,             # Salario base anual (o mensual, según convenga)
            "fecha_contratacion": str,    # Fecha de contratación en formato YYYY-MM-DD
            "desempeno": float,           # Valor numérico que represente el desempeño (ej. 0 a 10)
            "activo": bool                # Indica si el empleado sigue activo en la empresa
        }
        
        activo_dict = {
            "activo": True, "on": True, "1": True, "yes": True, "y": True, 1: True, "true": True, "t": True,
            "inactivo": False, "off": False, "0": False, "no": False, "n": False, 0: False, "false": False, "f": False
                      }
        
        valid_employees = []
        errors = []
        
        for i, dic in enumerate(self.employees):
            #verificar la existencia de claves:
            missing = [clave for clave in mandatory_keys.keys()
                         if clave not in dic]
            if missing:
                errors.append(f"Error en empleado {i}: faltan las claves: {missing}")
                self.logger.warning(f"Error en empleado {i}: faltan las claves: {missing}")
                continue
            
            #cambiar a boleano
            dic["activo"] = str(dic["activo"]).lower().strip()
            dic["activo"] = activo_dict.get(str(dic["activo"]).strip(), None)
            
            #ambiar a int/float
            dic["edad"] = int(dic["edad"])
            dic["salario"] = float(dic["salario"])
            dic["desempeno"] = float(dic["desempeno"])
            
            #comprobar fechas
            if dic.get("fecha_contratacion"):
                if isinstance(dic["fecha_contratacion"], str):
                    if not re.match(r"^\d{4}-\d{2}-\d{2}$", dic["fecha_contratacion"]):
                        errors.append(f"Error en empleado {i}: la fecha de contratación no es válida")
                        self.logger.warning(f"Error en empleado {i}: faltan las claves: {missing}")
                        continue
                
            empleado_valido = True
            for clave, tipo in mandatory_keys.items(): 
                if not isinstance(dic[clave], tipo):
                    errors.append(f"Error en empleado {i}: la clave '{clave}' no es del tipo {tipo.__name__}")
                    self.logger.warning(f"Error en empleado {i}: la clave '{clave}' no es del tipo {tipo.__name__}")
                    empleado_valido = False 
            if empleado_valido:
                valid_employees.append(dic)
        self.logger.info(f"Se creo la lista de empleados validos")
        return valid_employees, errors

# %%
class EmployerAnalyzer:
    def __init__(self, valid_employees, logger):
        self.valid_employees = valid_employees
        self.logger = logger
        self.total = len(valid_employees)
        
        #Cambiar el tipo de dato de fecha_contratacion a datetime.date
        for employee in self.valid_employees:
            if "fecha_contratacion" in employee and isinstance(employee["fecha_contratacion"], str):
                try:
                    employee["fecha_contratacion"] = datetime.datetime.strptime(employee["fecha_contratacion"], "%Y-%m-%d").date()
                except ValueError:
                    employee["fecha_contratacion"] = None
        self.logger.info(f"Se cambio el tipo de dato 'fecha_contratacion' de str a datetime")
        
    def get_average_salary(self):
        #calcular el salario promedio de los empleados
        if not self.valid_employees:
            self.logger.warning(f"No hay datos validos")
        else:
            average_salary = sum([employee["salario"] for employee in self.valid_employees]) / self.total
            self.logger.info(f"Se aplico el metodo get_average_salary")
            return round(average_salary, 2)
        
    def count_by_apartment(self):
        #contar la cantidad de empleados por departamento
        department_counter = {}
        for empleado in self.valid_employees:
            departament = empleado["departamento"]
            if departament not in department_counter:
                department_counter[departament] = 0
            department_counter[departament] += 1
        self.logger.info(f"Se aplico el metodo count_by_department")
        return department_counter
    
    def average_performance(self):
        #calcular el desempeño promedio de los empleados 
        performance_average = sum([employee["desempeno"] for employee in self.valid_employees]) / self.total
        self.logger.info(f"Se aplico el metodo average_performance")
        return round(performance_average, 2)
    
    def percentage_of_active_employees(self):
        #calcular el porcentaje de empleados activos
        
       active_employees = sum(1 for employee in self.valid_employees if employee["activo"] == True)
       percent_active_employees = (active_employees / self.total) * 100
       self.logger.info(f"Se aplico el metodo percentage_of_active_employees")
       return round(percent_active_employees, 2)
    
    def average_days_employed(self):
        #calcular el promedio de dias trabajados en la empresa
                    
       today= datetime.date.today()
       total_days = sum((today- employee["fecha_contratacion"]).days
                          for employee in self.valid_employees
                          if employee["fecha_contratacion"] is not None)
       average_days = total_days / self.total
       self.logger.info(f"Se aplico el metodo average_days_employeed")
       return round(average_days, 2)

# %%
#crear el logger
logger = Logger().get_logger()

# %%
#Abrir el archivo Json
data_file = ReadData("empleados.json", logger)
employee = data_file.read_json()
# Out:
# 2025-04-04 20:24:54,526 - App_Logger - INFO - Datos obtenidos de empleados.json

# %%
# Validar los datos
data_loader = EmployeeDataLoader(employee, logger)
datos_limpios, errores = data_loader.get_clean_data()
# Out:
# 2025-04-04 20:24:54,555 - App_Logger - WARNING - Error en empleado 11: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,557 - App_Logger - WARNING - Error en empleado 12: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,558 - App_Logger - WARNING - Error en empleado 21: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,559 - App_Logger - WARNING - Error en empleado 30: faltan las claves: ['edad']
# 2025-04-04 20:24:54,561 - App_Logger - WARNING - Error en empleado 35: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,562 - App_Logger - WARNING - Error en empleado 41: faltan las claves: ['edad']
# 2025-04-04 20:24:54,563 - App_Logger - WARNING - Error en empleado 48: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,564 - App_Logger - WARNING - Error en empleado 51: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,565 - App_Logger - WARNING - Error en empleado 66: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,566 - App_Logger - WARNING - Error en empleado 75: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,567 - App_Logger - WARNING - Error en empleado 91: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,568 - App_Logger - WARNING - Error en empleado 93: faltan las claves: ['edad']
# 2025-04-04 20:24:54,569 - App_Logger - WARNING - Error en empleado 99: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,570 - App_Logger - WARNING - Error en empleado 110: faltan las claves: ['edad']
# 2025-04-04 20:24:54,571 - App_Logger - WARNING - Error en empleado 115: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,572 - App_Logger - WARNING - Error en empleado 123: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,574 - App_Logger - WARNING - Error en empleado 146: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,574 - App_Logger - WARNING - Error en empleado 148: faltan las claves: ['edad']
# 2025-04-04 20:24:54,575 - App_Logger - WARNING - Error en empleado 169: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,577 - App_Logger - WARNING - Error en empleado 173: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,579 - App_Logger - WARNING - Error en empleado 180: faltan las claves: ['edad']
# 2025-04-04 20:24:54,579 - App_Logger - WARNING - Error en empleado 188: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,580 - App_Logger - WARNING - Error en empleado 194: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,581 - App_Logger - WARNING - Error en empleado 195: faltan las claves: ['edad']
# 2025-04-04 20:24:54,581 - App_Logger - WARNING - Error en empleado 197: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,582 - App_Logger - WARNING - Error en empleado 199: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,583 - App_Logger - WARNING - Error en empleado 205: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,584 - App_Logger - WARNING - Error en empleado 219: faltan las claves: ['edad']
# 2025-04-04 20:24:54,584 - App_Logger - WARNING - Error en empleado 220: faltan las claves: ['edad']
# 2025-04-04 20:24:54,585 - App_Logger - WARNING - Error en empleado 224: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,586 - App_Logger - WARNING - Error en empleado 231: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,587 - App_Logger - WARNING - Error en empleado 261: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,587 - App_Logger - WARNING - Error en empleado 283: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,588 - App_Logger - WARNING - Error en empleado 284: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,588 - App_Logger - WARNING - Error en empleado 286: faltan las claves: ['edad']
# 2025-04-04 20:24:54,589 - App_Logger - WARNING - Error en empleado 288: faltan las claves: ['edad']
# 2025-04-04 20:24:54,590 - App_Logger - WARNING - Error en empleado 291: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,591 - App_Logger - WARNING - Error en empleado 292: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,591 - App_Logger - WARNING - Error en empleado 293: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,593 - App_Logger - WARNING - Error en empleado 297: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,594 - App_Logger - WARNING - Error en empleado 301: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,595 - App_Logger - WARNING - Error en empleado 302: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,595 - App_Logger - WARNING - Error en empleado 312: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,596 - App_Logger - WARNING - Error en empleado 328: faltan las claves: ['edad']
# 2025-04-04 20:24:54,597 - App_Logger - WARNING - Error en empleado 333: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,597 - App_Logger - WARNING - Error en empleado 340: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,598 - App_Logger - WARNING - Error en empleado 341: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,599 - App_Logger - WARNING - Error en empleado 363: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:24:54,600 - App_Logger - WARNING - Error en empleado 372: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,600 - App_Logger - WARNING - Error en empleado 375: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,601 - App_Logger - WARNING - Error en empleado 379: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,602 - App_Logger - WARNING - Error en empleado 380: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,602 - App_Logger - WARNING - Error en empleado 383: faltan las claves: ['edad']
# 2025-04-04 20:24:54,603 - App_Logger - WARNING - Error en empleado 391: faltan las claves: ['edad']
# 2025-04-04 20:24:54,603 - App_Logger - WARNING - Error en empleado 398: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,605 - App_Logger - WARNING - Error en empleado 404: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,605 - App_Logger - WARNING - Error en empleado 405: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,606 - App_Logger - WARNING - Error en empleado 410: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,606 - App_Logger - WARNING - Error en empleado 418: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,607 - App_Logger - WARNING - Error en empleado 419: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,607 - App_Logger - WARNING - Error en empleado 420: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,608 - App_Logger - WARNING - Error en empleado 429: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,609 - App_Logger - WARNING - Error en empleado 433: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:24:54,609 - App_Logger - WARNING - Error en empleado 443: faltan las claves: ['edad']
# 2025-04-04 20:24:54,610 - App_Logger - WARNING - Error en empleado 448: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,610 - App_Logger - WARNING - Error en empleado 455: faltan las claves: ['edad']
# 2025-04-04 20:24:54,611 - App_Logger - WARNING - Error en empleado 463: faltan las claves: ['edad']
# 2025-04-04 20:24:54,612 - App_Logger - WARNING - Error en empleado 471: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,612 - App_Logger - WARNING - Error en empleado 476: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,613 - App_Logger - WARNING - Error en empleado 479: faltan las claves: ['edad']
# 2025-04-04 20:24:54,614 - App_Logger - WARNING - Error en empleado 484: faltan las claves: ['edad']
# 2025-04-04 20:24:54,615 - App_Logger - WARNING - Error en empleado 494: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:24:54,615 - App_Logger - WARNING - Error en empleado 504: faltan las claves: ['edad']
# 2025-04-04 20:24:54,616 - App_Logger - WARNING - Error en empleado 507: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,616 - App_Logger - WARNING - Error en empleado 513: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,617 - App_Logger - WARNING - Error en empleado 515: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,617 - App_Logger - WARNING - Error en empleado 516: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,618 - App_Logger - WARNING - Error en empleado 534: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,619 - App_Logger - WARNING - Error en empleado 535: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,619 - App_Logger - WARNING - Error en empleado 541: faltan las claves: ['edad']
# 2025-04-04 20:24:54,620 - App_Logger - WARNING - Error en empleado 542: faltan las claves: ['edad']
# 2025-04-04 20:24:54,620 - App_Logger - WARNING - Error en empleado 571: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,621 - App_Logger - WARNING - Error en empleado 572: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,622 - App_Logger - WARNING - Error en empleado 579: faltan las claves: ['edad']
# 2025-04-04 20:24:54,622 - App_Logger - WARNING - Error en empleado 594: faltan las claves: ['edad']
# 2025-04-04 20:24:54,623 - App_Logger - WARNING - Error en empleado 596: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,623 - App_Logger - WARNING - Error en empleado 598: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,624 - App_Logger - WARNING - Error en empleado 600: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,625 - App_Logger - WARNING - Error en empleado 631: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,626 - App_Logger - WARNING - Error en empleado 649: faltan las claves: ['edad']
# 2025-04-04 20:24:54,626 - App_Logger - WARNING - Error en empleado 656: faltan las claves: ['edad', 'fecha_contratacion']
# 2025-04-04 20:24:54,627 - App_Logger - WARNING - Error en empleado 665: faltan las claves: ['edad']
# 2025-04-04 20:24:54,627 - App_Logger - WARNING - Error en empleado 671: faltan las claves: ['edad']
# 2025-04-04 20:24:54,628 - App_Logger - WARNING - Error en empleado 682: faltan las claves: ['edad']
# 2025-04-04 20:24:54,628 - App_Logger - WARNING - Error en empleado 689: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,629 - App_Logger - WARNING - Error en empleado 692: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,630 - App_Logger - WARNING - Error en empleado 696: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,630 - App_Logger - WARNING - Error en empleado 702: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,631 - App_Logger - WARNING - Error en empleado 704: faltan las claves: ['edad']
# 2025-04-04 20:24:54,631 - App_Logger - WARNING - Error en empleado 705: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,632 - App_Logger - WARNING - Error en empleado 708: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,632 - App_Logger - WARNING - Error en empleado 712: faltan las claves: ['edad']
# 2025-04-04 20:24:54,633 - App_Logger - WARNING - Error en empleado 717: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,633 - App_Logger - WARNING - Error en empleado 718: faltan las claves: ['edad']
# 2025-04-04 20:24:54,634 - App_Logger - WARNING - Error en empleado 734: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,634 - App_Logger - WARNING - Error en empleado 743: faltan las claves: ['edad']
# 2025-04-04 20:24:54,635 - App_Logger - WARNING - Error en empleado 747: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,636 - App_Logger - WARNING - Error en empleado 755: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,636 - App_Logger - WARNING - Error en empleado 762: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,637 - App_Logger - WARNING - Error en empleado 768: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,637 - App_Logger - WARNING - Error en empleado 769: faltan las claves: ['edad']
# 2025-04-04 20:24:54,638 - App_Logger - WARNING - Error en empleado 770: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,638 - App_Logger - WARNING - Error en empleado 773: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,640 - App_Logger - WARNING - Error en empleado 784: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,640 - App_Logger - WARNING - Error en empleado 820: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,641 - App_Logger - WARNING - Error en empleado 830: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,642 - App_Logger - WARNING - Error en empleado 831: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,642 - App_Logger - WARNING - Error en empleado 833: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,643 - App_Logger - WARNING - Error en empleado 843: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,644 - App_Logger - WARNING - Error en empleado 850: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,644 - App_Logger - WARNING - Error en empleado 851: faltan las claves: ['edad']
# 2025-04-04 20:24:54,645 - App_Logger - WARNING - Error en empleado 858: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,646 - App_Logger - WARNING - Error en empleado 864: faltan las claves: ['edad']
# 2025-04-04 20:24:54,647 - App_Logger - WARNING - Error en empleado 877: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,648 - App_Logger - WARNING - Error en empleado 882: faltan las claves: ['edad']
# 2025-04-04 20:24:54,648 - App_Logger - WARNING - Error en empleado 898: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,649 - App_Logger - WARNING - Error en empleado 901: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,649 - App_Logger - WARNING - Error en empleado 908: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,650 - App_Logger - WARNING - Error en empleado 911: faltan las claves: ['edad']
# 2025-04-04 20:24:54,650 - App_Logger - WARNING - Error en empleado 912: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,651 - App_Logger - WARNING - Error en empleado 923: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,652 - App_Logger - WARNING - Error en empleado 927: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,652 - App_Logger - WARNING - Error en empleado 930: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,653 - App_Logger - WARNING - Error en empleado 933: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,653 - App_Logger - WARNING - Error en empleado 937: faltan las claves: ['edad']
# 2025-04-04 20:24:54,654 - App_Logger - WARNING - Error en empleado 951: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,655 - App_Logger - WARNING - Error en empleado 954: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,655 - App_Logger - WARNING - Error en empleado 966: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,656 - App_Logger - WARNING - Error en empleado 973: faltan las claves: ['edad']
# 2025-04-04 20:24:54,657 - App_Logger - WARNING - Error en empleado 975: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,657 - App_Logger - WARNING - Error en empleado 978: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,658 - App_Logger - WARNING - Error en empleado 998: faltan las claves: ['edad']
# 2025-04-04 20:24:54,658 - App_Logger - WARNING - Error en empleado 1003: faltan las claves: ['edad']
# 2025-04-04 20:24:54,659 - App_Logger - WARNING - Error en empleado 1019: faltan las claves: ['edad']
# 2025-04-04 20:24:54,659 - App_Logger - WARNING - Error en empleado 1023: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,660 - App_Logger - WARNING - Error en empleado 1027: faltan las claves: ['edad', 'fecha_contratacion']
# 2025-04-04 20:24:54,661 - App_Logger - WARNING - Error en empleado 1038: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,661 - App_Logger - WARNING - Error en empleado 1041: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,662 - App_Logger - WARNING - Error en empleado 1052: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:24:54,662 - App_Logger - WARNING - Error en empleado 1060: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,663 - App_Logger - WARNING - Error en empleado 1063: faltan las claves: ['edad']
# 2025-04-04 20:24:54,664 - App_Logger - WARNING - Error en empleado 1072: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,664 - App_Logger - WARNING - Error en empleado 1073: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,665 - App_Logger - WARNING - Error en empleado 1075: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,665 - App_Logger - WARNING - Error en empleado 1081: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,666 - App_Logger - WARNING - Error en empleado 1107: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,667 - App_Logger - WARNING - Error en empleado 1108: faltan las claves: ['edad']
# 2025-04-04 20:24:54,668 - App_Logger - WARNING - Error en empleado 1110: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,668 - App_Logger - WARNING - Error en empleado 1111: faltan las claves: ['edad']
# 2025-04-04 20:24:54,669 - App_Logger - WARNING - Error en empleado 1119: faltan las claves: ['edad']
# 2025-04-04 20:24:54,669 - App_Logger - WARNING - Error en empleado 1120: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,670 - App_Logger - WARNING - Error en empleado 1121: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,671 - App_Logger - WARNING - Error en empleado 1123: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,671 - App_Logger - WARNING - Error en empleado 1125: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,672 - App_Logger - WARNING - Error en empleado 1130: faltan las claves: ['edad']
# 2025-04-04 20:24:54,672 - App_Logger - WARNING - Error en empleado 1135: faltan las claves: ['edad']
# 2025-04-04 20:24:54,673 - App_Logger - WARNING - Error en empleado 1141: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,674 - App_Logger - WARNING - Error en empleado 1147: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,675 - App_Logger - WARNING - Error en empleado 1150: faltan las claves: ['edad']
# 2025-04-04 20:24:54,676 - App_Logger - WARNING - Error en empleado 1154: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,676 - App_Logger - WARNING - Error en empleado 1159: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,677 - App_Logger - WARNING - Error en empleado 1163: faltan las claves: ['edad']
# 2025-04-04 20:24:54,678 - App_Logger - WARNING - Error en empleado 1173: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,678 - App_Logger - WARNING - Error en empleado 1200: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,679 - App_Logger - WARNING - Error en empleado 1209: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,680 - App_Logger - WARNING - Error en empleado 1212: faltan las claves: ['edad']
# 2025-04-04 20:24:54,680 - App_Logger - WARNING - Error en empleado 1214: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,681 - App_Logger - WARNING - Error en empleado 1222: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,682 - App_Logger - WARNING - Error en empleado 1228: faltan las claves: ['edad']
# 2025-04-04 20:24:54,682 - App_Logger - WARNING - Error en empleado 1231: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,683 - App_Logger - WARNING - Error en empleado 1240: faltan las claves: ['edad']
# 2025-04-04 20:24:54,683 - App_Logger - WARNING - Error en empleado 1243: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,684 - App_Logger - WARNING - Error en empleado 1251: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,684 - App_Logger - WARNING - Error en empleado 1253: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,685 - App_Logger - WARNING - Error en empleado 1254: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,686 - App_Logger - WARNING - Error en empleado 1261: faltan las claves: ['edad']
# 2025-04-04 20:24:54,686 - App_Logger - WARNING - Error en empleado 1262: faltan las claves: ['edad']
# 2025-04-04 20:24:54,687 - App_Logger - WARNING - Error en empleado 1273: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,689 - App_Logger - WARNING - Error en empleado 1278: faltan las claves: ['edad']
# 2025-04-04 20:24:54,689 - App_Logger - WARNING - Error en empleado 1281: faltan las claves: ['edad']
# 2025-04-04 20:24:54,690 - App_Logger - WARNING - Error en empleado 1286: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,691 - App_Logger - WARNING - Error en empleado 1291: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,692 - App_Logger - WARNING - Error en empleado 1297: faltan las claves: ['edad']
# 2025-04-04 20:24:54,692 - App_Logger - WARNING - Error en empleado 1301: faltan las claves: ['edad']
# 2025-04-04 20:24:54,693 - App_Logger - WARNING - Error en empleado 1306: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,693 - App_Logger - WARNING - Error en empleado 1309: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,694 - App_Logger - WARNING - Error en empleado 1346: faltan las claves: ['edad']
# 2025-04-04 20:24:54,695 - App_Logger - WARNING - Error en empleado 1347: faltan las claves: ['edad']
# 2025-04-04 20:24:54,695 - App_Logger - WARNING - Error en empleado 1352: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,696 - App_Logger - WARNING - Error en empleado 1354: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,697 - App_Logger - WARNING - Error en empleado 1369: faltan las claves: ['edad']
# 2025-04-04 20:24:54,698 - App_Logger - WARNING - Error en empleado 1379: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,698 - App_Logger - WARNING - Error en empleado 1388: faltan las claves: ['edad']
# 2025-04-04 20:24:54,699 - App_Logger - WARNING - Error en empleado 1389: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,699 - App_Logger - WARNING - Error en empleado 1399: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,700 - App_Logger - WARNING - Error en empleado 1415: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,701 - App_Logger - WARNING - Error en empleado 1419: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:24:54,701 - App_Logger - WARNING - Error en empleado 1423: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,702 - App_Logger - WARNING - Error en empleado 1426: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,704 - App_Logger - WARNING - Error en empleado 1431: faltan las claves: ['edad']
# 2025-04-04 20:24:54,704 - App_Logger - WARNING - Error en empleado 1434: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,705 - App_Logger - WARNING - Error en empleado 1435: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,705 - App_Logger - WARNING - Error en empleado 1442: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,706 - App_Logger - WARNING - Error en empleado 1446: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,706 - App_Logger - WARNING - Error en empleado 1449: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,707 - App_Logger - WARNING - Error en empleado 1473: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,708 - App_Logger - WARNING - Error en empleado 1475: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,708 - App_Logger - WARNING - Error en empleado 1489: faltan las claves: ['edad']
# 2025-04-04 20:24:54,709 - App_Logger - WARNING - Error en empleado 1495: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,710 - App_Logger - WARNING - Error en empleado 1496: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:24:54,711 - App_Logger - WARNING - Error en empleado 1505: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,711 - App_Logger - WARNING - Error en empleado 1507: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,712 - App_Logger - WARNING - Error en empleado 1516: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,713 - App_Logger - WARNING - Error en empleado 1519: faltan las claves: ['edad']
# 2025-04-04 20:24:54,713 - App_Logger - WARNING - Error en empleado 1523: faltan las claves: ['edad']
# 2025-04-04 20:24:54,714 - App_Logger - WARNING - Error en empleado 1526: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,714 - App_Logger - WARNING - Error en empleado 1527: faltan las claves: ['edad']
# 2025-04-04 20:24:54,715 - App_Logger - WARNING - Error en empleado 1543: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,716 - App_Logger - WARNING - Error en empleado 1547: faltan las claves: ['edad']
# 2025-04-04 20:24:54,716 - App_Logger - WARNING - Error en empleado 1548: faltan las claves: ['edad']
# 2025-04-04 20:24:54,717 - App_Logger - WARNING - Error en empleado 1550: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,717 - App_Logger - WARNING - Error en empleado 1551: faltan las claves: ['edad']
# 2025-04-04 20:24:54,718 - App_Logger - WARNING - Error en empleado 1552: faltan las claves: ['edad']
# 2025-04-04 20:24:54,719 - App_Logger - WARNING - Error en empleado 1553: faltan las claves: ['edad']
# 2025-04-04 20:24:54,720 - App_Logger - WARNING - Error en empleado 1555: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,720 - App_Logger - WARNING - Error en empleado 1566: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,721 - App_Logger - WARNING - Error en empleado 1569: faltan las claves: ['edad']
# 2025-04-04 20:24:54,721 - App_Logger - WARNING - Error en empleado 1570: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,722 - App_Logger - WARNING - Error en empleado 1575: faltan las claves: ['edad']
# 2025-04-04 20:24:54,723 - App_Logger - WARNING - Error en empleado 1577: faltan las claves: ['edad']
# 2025-04-04 20:24:54,724 - App_Logger - WARNING - Error en empleado 1589: faltan las claves: ['edad']
# 2025-04-04 20:24:54,724 - App_Logger - WARNING - Error en empleado 1599: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,725 - App_Logger - WARNING - Error en empleado 1603: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,725 - App_Logger - WARNING - Error en empleado 1611: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,726 - App_Logger - WARNING - Error en empleado 1619: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,727 - App_Logger - WARNING - Error en empleado 1630: faltan las claves: ['edad']
# 2025-04-04 20:24:54,727 - App_Logger - WARNING - Error en empleado 1631: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,728 - App_Logger - WARNING - Error en empleado 1638: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,728 - App_Logger - WARNING - Error en empleado 1642: faltan las claves: ['edad']
# 2025-04-04 20:24:54,729 - App_Logger - WARNING - Error en empleado 1645: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,729 - App_Logger - WARNING - Error en empleado 1678: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:24:54,730 - App_Logger - WARNING - Error en empleado 1680: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:24:54,731 - App_Logger - WARNING - Error en empleado 1690: faltan las claves: ['edad', 'fecha_contratacion']
# 2025-04-04 20:24:54,732 - App_Logger - WARNING - Error en empleado 1714: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,733 - App_Logger - WARNING - Error en empleado 1719: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,734 - App_Logger - WARNING - Error en empleado 1730: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,734 - App_Logger - WARNING - Error en empleado 1731: faltan las claves: ['edad']
# 2025-04-04 20:24:54,735 - App_Logger - WARNING - Error en empleado 1733: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,735 - App_Logger - WARNING - Error en empleado 1734: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,736 - App_Logger - WARNING - Error en empleado 1745: faltan las claves: ['edad']
# 2025-04-04 20:24:54,737 - App_Logger - WARNING - Error en empleado 1762: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,737 - App_Logger - WARNING - Error en empleado 1790: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,738 - App_Logger - WARNING - Error en empleado 1799: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,739 - App_Logger - WARNING - Error en empleado 1808: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,739 - App_Logger - WARNING - Error en empleado 1812: faltan las claves: ['edad']
# 2025-04-04 20:24:54,740 - App_Logger - WARNING - Error en empleado 1820: faltan las claves: ['edad']
# 2025-04-04 20:24:54,741 - App_Logger - WARNING - Error en empleado 1838: faltan las claves: ['edad']
# 2025-04-04 20:24:54,741 - App_Logger - WARNING - Error en empleado 1843: faltan las claves: ['edad']
# 2025-04-04 20:24:54,742 - App_Logger - WARNING - Error en empleado 1846: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,743 - App_Logger - WARNING - Error en empleado 1847: faltan las claves: ['edad']
# 2025-04-04 20:24:54,744 - App_Logger - WARNING - Error en empleado 1857: faltan las claves: ['edad', 'fecha_contratacion']
# 2025-04-04 20:24:54,745 - App_Logger - WARNING - Error en empleado 1868: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,745 - App_Logger - WARNING - Error en empleado 1888: faltan las claves: ['edad']
# 2025-04-04 20:24:54,746 - App_Logger - WARNING - Error en empleado 1898: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,747 - App_Logger - WARNING - Error en empleado 1904: faltan las claves: ['edad']
# 2025-04-04 20:24:54,747 - App_Logger - WARNING - Error en empleado 1909: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,748 - App_Logger - WARNING - Error en empleado 1910: faltan las claves: ['edad']
# 2025-04-04 20:24:54,748 - App_Logger - WARNING - Error en empleado 1919: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,749 - App_Logger - WARNING - Error en empleado 1922: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,750 - App_Logger - WARNING - Error en empleado 1924: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,750 - App_Logger - WARNING - Error en empleado 1927: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,751 - App_Logger - WARNING - Error en empleado 1929: faltan las claves: ['edad']
# 2025-04-04 20:24:54,752 - App_Logger - WARNING - Error en empleado 1946: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,752 - App_Logger - WARNING - Error en empleado 1948: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:24:54,753 - App_Logger - WARNING - Error en empleado 1950: faltan las claves: ['edad']
# 2025-04-04 20:24:54,753 - App_Logger - WARNING - Error en empleado 1954: faltan las claves: ['edad']
# 2025-04-04 20:24:54,754 - App_Logger - WARNING - Error en empleado 1960: faltan las claves: ['edad']
# 2025-04-04 20:24:54,754 - App_Logger - WARNING - Error en empleado 1971: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,755 - App_Logger - WARNING - Error en empleado 1973: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,755 - App_Logger - WARNING - Error en empleado 1976: faltan las claves: ['edad']
# 2025-04-04 20:24:54,756 - App_Logger - WARNING - Error en empleado 1980: faltan las claves: ['edad']
# 2025-04-04 20:24:54,756 - App_Logger - WARNING - Error en empleado 1981: faltan las claves: ['edad']
# 2025-04-04 20:24:54,757 - App_Logger - WARNING - Error en empleado 1988: faltan las claves: ['edad']
# 2025-04-04 20:24:54,758 - App_Logger - WARNING - Error en empleado 1989: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,759 - App_Logger - WARNING - Error en empleado 1995: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,759 - App_Logger - WARNING - Error en empleado 1996: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,760 - App_Logger - WARNING - Error en empleado 2003: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,760 - App_Logger - WARNING - Error en empleado 2032: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,761 - App_Logger - WARNING - Error en empleado 2036: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,761 - App_Logger - WARNING - Error en empleado 2037: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,762 - App_Logger - WARNING - Error en empleado 2042: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,762 - App_Logger - WARNING - Error en empleado 2044: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,763 - App_Logger - WARNING - Error en empleado 2052: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,764 - App_Logger - WARNING - Error en empleado 2053: faltan las claves: ['edad']
# 2025-04-04 20:24:54,765 - App_Logger - WARNING - Error en empleado 2058: faltan las claves: ['edad']
# 2025-04-04 20:24:54,766 - App_Logger - WARNING - Error en empleado 2061: faltan las claves: ['edad']
# 2025-04-04 20:24:54,766 - App_Logger - WARNING - Error en empleado 2064: faltan las claves: ['edad']
# 2025-04-04 20:24:54,766 - App_Logger - WARNING - Error en empleado 2067: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,767 - App_Logger - WARNING - Error en empleado 2073: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,768 - App_Logger - WARNING - Error en empleado 2075: faltan las claves: ['edad']
# 2025-04-04 20:24:54,768 - App_Logger - WARNING - Error en empleado 2085: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,769 - App_Logger - WARNING - Error en empleado 2092: faltan las claves: ['edad']
# 2025-04-04 20:24:54,769 - App_Logger - WARNING - Error en empleado 2098: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,770 - App_Logger - WARNING - Error en empleado 2101: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,770 - App_Logger - WARNING - Error en empleado 2103: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,771 - App_Logger - WARNING - Error en empleado 2108: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,772 - App_Logger - WARNING - Error en empleado 2111: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,773 - App_Logger - WARNING - Error en empleado 2113: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,773 - App_Logger - WARNING - Error en empleado 2126: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,774 - App_Logger - WARNING - Error en empleado 2133: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,774 - App_Logger - WARNING - Error en empleado 2137: faltan las claves: ['edad']
# 2025-04-04 20:24:54,775 - App_Logger - WARNING - Error en empleado 2140: faltan las claves: ['edad']
# 2025-04-04 20:24:54,775 - App_Logger - WARNING - Error en empleado 2148: faltan las claves: ['edad']
# 2025-04-04 20:24:54,776 - App_Logger - WARNING - Error en empleado 2150: faltan las claves: ['edad']
# 2025-04-04 20:24:54,776 - App_Logger - WARNING - Error en empleado 2157: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,777 - App_Logger - WARNING - Error en empleado 2168: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,778 - App_Logger - WARNING - Error en empleado 2173: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,778 - App_Logger - WARNING - Error en empleado 2174: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,779 - App_Logger - WARNING - Error en empleado 2197: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,780 - App_Logger - WARNING - Error en empleado 2203: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,781 - App_Logger - WARNING - Error en empleado 2219: faltan las claves: ['edad']
# 2025-04-04 20:24:54,782 - App_Logger - WARNING - Error en empleado 2224: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,782 - App_Logger - WARNING - Error en empleado 2227: faltan las claves: ['edad']
# 2025-04-04 20:24:54,783 - App_Logger - WARNING - Error en empleado 2235: faltan las claves: ['edad']
# 2025-04-04 20:24:54,784 - App_Logger - WARNING - Error en empleado 2248: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,784 - App_Logger - WARNING - Error en empleado 2256: faltan las claves: ['edad']
# 2025-04-04 20:24:54,785 - App_Logger - WARNING - Error en empleado 2263: faltan las claves: ['edad']
# 2025-04-04 20:24:54,786 - App_Logger - WARNING - Error en empleado 2267: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,787 - App_Logger - WARNING - Error en empleado 2269: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,788 - App_Logger - WARNING - Error en empleado 2272: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,788 - App_Logger - WARNING - Error en empleado 2273: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,789 - App_Logger - WARNING - Error en empleado 2278: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,789 - App_Logger - WARNING - Error en empleado 2279: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,790 - App_Logger - WARNING - Error en empleado 2292: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,790 - App_Logger - WARNING - Error en empleado 2317: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,791 - App_Logger - WARNING - Error en empleado 2318: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,792 - App_Logger - WARNING - Error en empleado 2334: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,792 - App_Logger - WARNING - Error en empleado 2336: faltan las claves: ['edad']
# 2025-04-04 20:24:54,793 - App_Logger - WARNING - Error en empleado 2337: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,794 - App_Logger - WARNING - Error en empleado 2351: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,794 - App_Logger - WARNING - Error en empleado 2354: faltan las claves: ['edad']
# 2025-04-04 20:24:54,795 - App_Logger - WARNING - Error en empleado 2375: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,796 - App_Logger - WARNING - Error en empleado 2382: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,796 - App_Logger - WARNING - Error en empleado 2388: faltan las claves: ['edad']
# 2025-04-04 20:24:54,797 - App_Logger - WARNING - Error en empleado 2395: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,797 - App_Logger - WARNING - Error en empleado 2401: faltan las claves: ['edad']
# 2025-04-04 20:24:54,798 - App_Logger - WARNING - Error en empleado 2405: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,799 - App_Logger - WARNING - Error en empleado 2409: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,800 - App_Logger - WARNING - Error en empleado 2411: faltan las claves: ['edad']
# 2025-04-04 20:24:54,800 - App_Logger - WARNING - Error en empleado 2429: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,801 - App_Logger - WARNING - Error en empleado 2438: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,801 - App_Logger - WARNING - Error en empleado 2443: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,802 - App_Logger - WARNING - Error en empleado 2444: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,802 - App_Logger - WARNING - Error en empleado 2451: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,803 - App_Logger - WARNING - Error en empleado 2460: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,804 - App_Logger - WARNING - Error en empleado 2468: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,804 - App_Logger - WARNING - Error en empleado 2479: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,804 - App_Logger - WARNING - Error en empleado 2483: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,805 - App_Logger - WARNING - Error en empleado 2487: faltan las claves: ['edad']
# 2025-04-04 20:24:54,806 - App_Logger - WARNING - Error en empleado 2501: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,807 - App_Logger - WARNING - Error en empleado 2503: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,807 - App_Logger - WARNING - Error en empleado 2506: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,808 - App_Logger - WARNING - Error en empleado 2518: faltan las claves: ['edad']
# 2025-04-04 20:24:54,808 - App_Logger - WARNING - Error en empleado 2523: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,809 - App_Logger - WARNING - Error en empleado 2524: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,810 - App_Logger - WARNING - Error en empleado 2526: faltan las claves: ['edad']
# 2025-04-04 20:24:54,811 - App_Logger - WARNING - Error en empleado 2541: faltan las claves: ['edad']
# 2025-04-04 20:24:54,812 - App_Logger - WARNING - Error en empleado 2548: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,812 - App_Logger - WARNING - Error en empleado 2550: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,813 - App_Logger - WARNING - Error en empleado 2553: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,813 - App_Logger - WARNING - Error en empleado 2554: faltan las claves: ['edad']
# 2025-04-04 20:24:54,814 - App_Logger - WARNING - Error en empleado 2557: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:24:54,815 - App_Logger - WARNING - Error en empleado 2564: faltan las claves: ['edad']
# 2025-04-04 20:24:54,816 - App_Logger - WARNING - Error en empleado 2569: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:24:54,816 - App_Logger - WARNING - Error en empleado 2570: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,817 - App_Logger - WARNING - Error en empleado 2577: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,818 - App_Logger - WARNING - Error en empleado 2580: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,818 - App_Logger - WARNING - Error en empleado 2595: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,819 - App_Logger - WARNING - Error en empleado 2602: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,819 - App_Logger - WARNING - Error en empleado 2614: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,820 - App_Logger - WARNING - Error en empleado 2630: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,821 - App_Logger - WARNING - Error en empleado 2633: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:24:54,821 - App_Logger - WARNING - Error en empleado 2634: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,822 - App_Logger - WARNING - Error en empleado 2636: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,822 - App_Logger - WARNING - Error en empleado 2637: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,823 - App_Logger - WARNING - Error en empleado 2638: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,823 - App_Logger - WARNING - Error en empleado 2646: faltan las claves: ['edad']
# 2025-04-04 20:24:54,824 - App_Logger - WARNING - Error en empleado 2650: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,825 - App_Logger - WARNING - Error en empleado 2665: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,825 - App_Logger - WARNING - Error en empleado 2670: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,826 - App_Logger - WARNING - Error en empleado 2686: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,827 - App_Logger - WARNING - Error en empleado 2693: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,828 - App_Logger - WARNING - Error en empleado 2698: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,829 - App_Logger - WARNING - Error en empleado 2705: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,830 - App_Logger - WARNING - Error en empleado 2708: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,831 - App_Logger - WARNING - Error en empleado 2720: faltan las claves: ['edad']
# 2025-04-04 20:24:54,832 - App_Logger - WARNING - Error en empleado 2721: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,833 - App_Logger - WARNING - Error en empleado 2722: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,834 - App_Logger - WARNING - Error en empleado 2734: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,835 - App_Logger - WARNING - Error en empleado 2738: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,836 - App_Logger - WARNING - Error en empleado 2739: faltan las claves: ['edad']
# 2025-04-04 20:24:54,836 - App_Logger - WARNING - Error en empleado 2742: faltan las claves: ['edad', 'fecha_contratacion']
# 2025-04-04 20:24:54,837 - App_Logger - WARNING - Error en empleado 2747: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,837 - App_Logger - WARNING - Error en empleado 2757: faltan las claves: ['edad']
# 2025-04-04 20:24:54,838 - App_Logger - WARNING - Error en empleado 2768: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,839 - App_Logger - WARNING - Error en empleado 2774: faltan las claves: ['edad']
# 2025-04-04 20:24:54,840 - App_Logger - WARNING - Error en empleado 2803: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,840 - App_Logger - WARNING - Error en empleado 2811: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,841 - App_Logger - WARNING - Error en empleado 2812: faltan las claves: ['edad']
# 2025-04-04 20:24:54,841 - App_Logger - WARNING - Error en empleado 2819: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,842 - App_Logger - WARNING - Error en empleado 2855: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,843 - App_Logger - WARNING - Error en empleado 2863: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,844 - App_Logger - WARNING - Error en empleado 2871: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,844 - App_Logger - WARNING - Error en empleado 2878: faltan las claves: ['edad']
# 2025-04-04 20:24:54,845 - App_Logger - WARNING - Error en empleado 2880: faltan las claves: ['edad']
# 2025-04-04 20:24:54,846 - App_Logger - WARNING - Error en empleado 2885: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,846 - App_Logger - WARNING - Error en empleado 2898: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,847 - App_Logger - WARNING - Error en empleado 2907: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,848 - App_Logger - WARNING - Error en empleado 2910: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,849 - App_Logger - WARNING - Error en empleado 2913: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,849 - App_Logger - WARNING - Error en empleado 2914: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,850 - App_Logger - WARNING - Error en empleado 2923: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,851 - App_Logger - WARNING - Error en empleado 2928: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,852 - App_Logger - WARNING - Error en empleado 2936: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,852 - App_Logger - WARNING - Error en empleado 2937: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,853 - App_Logger - WARNING - Error en empleado 2944: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:24:54,854 - App_Logger - WARNING - Error en empleado 2945: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,855 - App_Logger - WARNING - Error en empleado 2950: faltan las claves: ['edad']
# 2025-04-04 20:24:54,855 - App_Logger - WARNING - Error en empleado 2957: faltan las claves: ['edad']
# 2025-04-04 20:24:54,856 - App_Logger - WARNING - Error en empleado 2960: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,856 - App_Logger - WARNING - Error en empleado 2961: faltan las claves: ['edad']
# 2025-04-04 20:24:54,857 - App_Logger - WARNING - Error en empleado 2962: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,858 - App_Logger - WARNING - Error en empleado 2976: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,858 - App_Logger - WARNING - Error en empleado 2977: faltan las claves: ['telefono']
# 2025-04-04 20:24:54,859 - App_Logger - WARNING - Error en empleado 2979: faltan las claves: ['edad']
# 2025-04-04 20:24:54,860 - App_Logger - WARNING - Error en empleado 2983: la clave 'activo' no es del tipo bool
# 2025-04-04 20:24:54,860 - App_Logger - WARNING - Error en empleado 2995: faltan las claves: ['edad']
# ...
# 2025-04-04 20:25:09,111 - App_Logger - WARNING - Error en empleado 99036: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,112 - App_Logger - WARNING - Error en empleado 99039: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,113 - App_Logger - WARNING - Error en empleado 99043: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,114 - App_Logger - WARNING - Error en empleado 99044: faltan las claves: ['edad']
# 2025-04-04 20:25:09,114 - App_Logger - WARNING - Error en empleado 99045: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,114 - App_Logger - WARNING - Error en empleado 99046: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,116 - App_Logger - WARNING - Error en empleado 99052: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,117 - App_Logger - WARNING - Error en empleado 99054: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,118 - App_Logger - WARNING - Error en empleado 99057: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:25:09,119 - App_Logger - WARNING - Error en empleado 99060: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,120 - App_Logger - WARNING - Error en empleado 99075: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:25:09,122 - App_Logger - WARNING - Error en empleado 99081: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,122 - App_Logger - WARNING - Error en empleado 99088: faltan las claves: ['edad']
# 2025-04-04 20:25:09,123 - App_Logger - WARNING - Error en empleado 99092: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,124 - App_Logger - WARNING - Error en empleado 99104: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,125 - App_Logger - WARNING - Error en empleado 99106: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,125 - App_Logger - WARNING - Error en empleado 99107: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,126 - App_Logger - WARNING - Error en empleado 99120: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,127 - App_Logger - WARNING - Error en empleado 99123: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,128 - App_Logger - WARNING - Error en empleado 99137: faltan las claves: ['edad']
# 2025-04-04 20:25:09,129 - App_Logger - WARNING - Error en empleado 99141: faltan las claves: ['edad']
# 2025-04-04 20:25:09,129 - App_Logger - WARNING - Error en empleado 99145: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,130 - App_Logger - WARNING - Error en empleado 99158: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,130 - App_Logger - WARNING - Error en empleado 99162: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,131 - App_Logger - WARNING - Error en empleado 99163: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,131 - App_Logger - WARNING - Error en empleado 99164: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,132 - App_Logger - WARNING - Error en empleado 99175: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,133 - App_Logger - WARNING - Error en empleado 99178: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,133 - App_Logger - WARNING - Error en empleado 99183: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,134 - App_Logger - WARNING - Error en empleado 99185: faltan las claves: ['edad']
# 2025-04-04 20:25:09,134 - App_Logger - WARNING - Error en empleado 99186: faltan las claves: ['edad']
# 2025-04-04 20:25:09,135 - App_Logger - WARNING - Error en empleado 99187: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,135 - App_Logger - WARNING - Error en empleado 99190: faltan las claves: ['edad']
# 2025-04-04 20:25:09,136 - App_Logger - WARNING - Error en empleado 99193: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,136 - App_Logger - WARNING - Error en empleado 99212: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,137 - App_Logger - WARNING - Error en empleado 99225: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:25:09,137 - App_Logger - WARNING - Error en empleado 99232: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,138 - App_Logger - WARNING - Error en empleado 99249: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,139 - App_Logger - WARNING - Error en empleado 99255: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,141 - App_Logger - WARNING - Error en empleado 99256: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,141 - App_Logger - WARNING - Error en empleado 99257: faltan las claves: ['edad']
# 2025-04-04 20:25:09,142 - App_Logger - WARNING - Error en empleado 99284: faltan las claves: ['edad']
# 2025-04-04 20:25:09,143 - App_Logger - WARNING - Error en empleado 99291: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,143 - App_Logger - WARNING - Error en empleado 99301: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,143 - App_Logger - WARNING - Error en empleado 99322: faltan las claves: ['edad', 'fecha_contratacion']
# 2025-04-04 20:25:09,144 - App_Logger - WARNING - Error en empleado 99325: faltan las claves: ['edad', 'telefono']
# 2025-04-04 20:25:09,144 - App_Logger - WARNING - Error en empleado 99328: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,145 - App_Logger - WARNING - Error en empleado 99338: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,146 - App_Logger - WARNING - Error en empleado 99341: faltan las claves: ['edad']
# 2025-04-04 20:25:09,146 - App_Logger - WARNING - Error en empleado 99355: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,147 - App_Logger - WARNING - Error en empleado 99357: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,147 - App_Logger - WARNING - Error en empleado 99361: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,148 - App_Logger - WARNING - Error en empleado 99364: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,148 - App_Logger - WARNING - Error en empleado 99365: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,149 - App_Logger - WARNING - Error en empleado 99377: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,149 - App_Logger - WARNING - Error en empleado 99384: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,151 - App_Logger - WARNING - Error en empleado 99387: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,151 - App_Logger - WARNING - Error en empleado 99389: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,152 - App_Logger - WARNING - Error en empleado 99395: faltan las claves: ['edad']
# 2025-04-04 20:25:09,153 - App_Logger - WARNING - Error en empleado 99397: faltan las claves: ['edad']
# 2025-04-04 20:25:09,153 - App_Logger - WARNING - Error en empleado 99402: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,154 - App_Logger - WARNING - Error en empleado 99406: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,154 - App_Logger - WARNING - Error en empleado 99418: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,155 - App_Logger - WARNING - Error en empleado 99428: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,157 - App_Logger - WARNING - Error en empleado 99432: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,157 - App_Logger - WARNING - Error en empleado 99436: faltan las claves: ['edad']
# 2025-04-04 20:25:09,158 - App_Logger - WARNING - Error en empleado 99450: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,158 - App_Logger - WARNING - Error en empleado 99452: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,159 - App_Logger - WARNING - Error en empleado 99459: faltan las claves: ['edad']
# 2025-04-04 20:25:09,159 - App_Logger - WARNING - Error en empleado 99462: faltan las claves: ['edad']
# 2025-04-04 20:25:09,160 - App_Logger - WARNING - Error en empleado 99473: faltan las claves: ['edad']
# 2025-04-04 20:25:09,161 - App_Logger - WARNING - Error en empleado 99475: faltan las claves: ['edad']
# 2025-04-04 20:25:09,161 - App_Logger - WARNING - Error en empleado 99487: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,162 - App_Logger - WARNING - Error en empleado 99498: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,162 - App_Logger - WARNING - Error en empleado 99516: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,163 - App_Logger - WARNING - Error en empleado 99523: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,163 - App_Logger - WARNING - Error en empleado 99526: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:25:09,164 - App_Logger - WARNING - Error en empleado 99534: faltan las claves: ['edad']
# 2025-04-04 20:25:09,164 - App_Logger - WARNING - Error en empleado 99539: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,165 - App_Logger - WARNING - Error en empleado 99543: faltan las claves: ['edad']
# 2025-04-04 20:25:09,165 - App_Logger - WARNING - Error en empleado 99548: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,165 - App_Logger - WARNING - Error en empleado 99556: faltan las claves: ['edad']
# 2025-04-04 20:25:09,166 - App_Logger - WARNING - Error en empleado 99559: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,167 - App_Logger - WARNING - Error en empleado 99564: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,167 - App_Logger - WARNING - Error en empleado 99565: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,168 - App_Logger - WARNING - Error en empleado 99566: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,168 - App_Logger - WARNING - Error en empleado 99582: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,169 - App_Logger - WARNING - Error en empleado 99617: faltan las claves: ['edad']
# 2025-04-04 20:25:09,169 - App_Logger - WARNING - Error en empleado 99618: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,170 - App_Logger - WARNING - Error en empleado 99621: faltan las claves: ['edad']
# 2025-04-04 20:25:09,171 - App_Logger - WARNING - Error en empleado 99633: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,172 - App_Logger - WARNING - Error en empleado 99639: faltan las claves: ['edad']
# 2025-04-04 20:25:09,173 - App_Logger - WARNING - Error en empleado 99640: faltan las claves: ['edad']
# 2025-04-04 20:25:09,174 - App_Logger - WARNING - Error en empleado 99648: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,176 - App_Logger - WARNING - Error en empleado 99666: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,176 - App_Logger - WARNING - Error en empleado 99667: faltan las claves: ['edad']
# 2025-04-04 20:25:09,177 - App_Logger - WARNING - Error en empleado 99668: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,177 - App_Logger - WARNING - Error en empleado 99674: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,178 - App_Logger - WARNING - Error en empleado 99677: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,178 - App_Logger - WARNING - Error en empleado 99696: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:25:09,179 - App_Logger - WARNING - Error en empleado 99697: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,179 - App_Logger - WARNING - Error en empleado 99699: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,180 - App_Logger - WARNING - Error en empleado 99702: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,180 - App_Logger - WARNING - Error en empleado 99705: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,181 - App_Logger - WARNING - Error en empleado 99708: faltan las claves: ['edad']
# 2025-04-04 20:25:09,182 - App_Logger - WARNING - Error en empleado 99711: faltan las claves: ['edad']
# 2025-04-04 20:25:09,182 - App_Logger - WARNING - Error en empleado 99712: faltan las claves: ['edad']
# 2025-04-04 20:25:09,183 - App_Logger - WARNING - Error en empleado 99730: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,183 - App_Logger - WARNING - Error en empleado 99738: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:25:09,184 - App_Logger - WARNING - Error en empleado 99744: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,184 - App_Logger - WARNING - Error en empleado 99746: faltan las claves: ['edad']
# 2025-04-04 20:25:09,185 - App_Logger - WARNING - Error en empleado 99758: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,186 - App_Logger - WARNING - Error en empleado 99759: faltan las claves: ['edad']
# 2025-04-04 20:25:09,186 - App_Logger - WARNING - Error en empleado 99761: faltan las claves: ['edad']
# 2025-04-04 20:25:09,187 - App_Logger - WARNING - Error en empleado 99776: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,187 - App_Logger - WARNING - Error en empleado 99779: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,188 - App_Logger - WARNING - Error en empleado 99785: faltan las claves: ['edad']
# 2025-04-04 20:25:09,188 - App_Logger - WARNING - Error en empleado 99787: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:25:09,189 - App_Logger - WARNING - Error en empleado 99800: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,190 - App_Logger - WARNING - Error en empleado 99807: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,190 - App_Logger - WARNING - Error en empleado 99813: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:25:09,191 - App_Logger - WARNING - Error en empleado 99829: faltan las claves: ['telefono', 'fecha_contratacion']
# 2025-04-04 20:25:09,191 - App_Logger - WARNING - Error en empleado 99831: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,192 - App_Logger - WARNING - Error en empleado 99839: faltan las claves: ['edad']
# 2025-04-04 20:25:09,193 - App_Logger - WARNING - Error en empleado 99844: faltan las claves: ['edad', 'fecha_contratacion']
# 2025-04-04 20:25:09,194 - App_Logger - WARNING - Error en empleado 99847: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,195 - App_Logger - WARNING - Error en empleado 99849: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,196 - App_Logger - WARNING - Error en empleado 99850: faltan las claves: ['edad']
# 2025-04-04 20:25:09,197 - App_Logger - WARNING - Error en empleado 99871: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,197 - App_Logger - WARNING - Error en empleado 99874: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,197 - App_Logger - WARNING - Error en empleado 99904: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,198 - App_Logger - WARNING - Error en empleado 99906: faltan las claves: ['edad']
# 2025-04-04 20:25:09,199 - App_Logger - WARNING - Error en empleado 99909: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,199 - App_Logger - WARNING - Error en empleado 99910: la clave 'activo' no es del tipo bool
# 2025-04-04 20:25:09,200 - App_Logger - WARNING - Error en empleado 99923: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,200 - App_Logger - WARNING - Error en empleado 99924: faltan las claves: ['edad']
# 2025-04-04 20:25:09,201 - App_Logger - WARNING - Error en empleado 99929: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,201 - App_Logger - WARNING - Error en empleado 99937: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,202 - App_Logger - WARNING - Error en empleado 99941: faltan las claves: ['edad']
# 2025-04-04 20:25:09,203 - App_Logger - WARNING - Error en empleado 99953: faltan las claves: ['edad']
# 2025-04-04 20:25:09,203 - App_Logger - WARNING - Error en empleado 99964: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,204 - App_Logger - WARNING - Error en empleado 99967: faltan las claves: ['fecha_contratacion']
# 2025-04-04 20:25:09,205 - App_Logger - WARNING - Error en empleado 99978: faltan las claves: ['telefono']
# 2025-04-04 20:25:09,206 - App_Logger - WARNING - Error en empleado 99996: faltan las claves: ['edad']
# 2025-04-04 20:25:09,206 - App_Logger - INFO - Se creo la lista de empleados validos

# %%
class EmployeeReportGenerator(EmployerAnalyzer):
    def __init__(self, valid_employees, logger):
        super().__init__(valid_employees, logger)
        self.logger = logger
        
    def generate_text_report(self, filename = "reporte.pdf"):
        pdf = FPDF()
        pdf.add_page()
        pdf.set_font("Arial", size=12)
        
        pdf.set_font("Arial", 'B', 16)
        pdf.cell(200, 10, txt="Reporte de Empleados", ln=True, align='C')
        pdf.ln(10)
        self.logger.info(f"Se aplicaron valores de creacion de reporte en PDF")
        
        pdf.set_font("Arial", size=12)
        pdf.cell(200, 10, txt=f"Total de empleados: {self.total}", ln = True)
        pdf.cell(200, 10, txt=f"Salario promedio: ${self.get_average_salary()}", ln = True)
        pdf.cell(200, 10, txt=f"Desempeño promedio: {self.average_performance()}", ln = True)
        pdf.cell(200, 10, txt=f"Porcentaje de empleados activos: {self.percentage_of_active_employees()}%", ln = True)
        pdf.cell(200, 10, txt=f"Promedio de días trabajados: {self.average_days_employed()} días", ln = True)
        
        pdf.ln(10)
        pdf.set_font("Arial", 'B', 12)
        pdf.cell(200, 10, txt="\nCantidad de empleados por departamento:", ln = True)
        pdf.set_font("Arial", size=12)
            
        for department, quantity in self.count_by_apartment().items():
            pdf.cell(200, 10, txt=f"{department}: {quantity} empleados", ln = True)
        pdf.output(filename)
        self.logger.info(f"Se aplico el metodo generate_text_report")
        return filename

# %%
report_generator = EmployeeReportGenerator(datos_limpios, logger)

    # Generar y mostrar el reporte
report = report_generator.generate_text_report()
print(report)
# Out:
# 2025-04-04 20:25:09,717 - App_Logger - INFO - Se cambio el tipo de dato 'fecha_contratacion' de str a datetime
# 2025-04-04 20:25:09,720 - App_Logger - INFO - Se aplicaron valores de creacion de reporte en PDF
# 2025-04-04 20:25:09,754 - App_Logger - INFO - Se aplico el metodo get_average_salary
# 2025-04-04 20:25:09,784 - App_Logger - INFO - Se aplico el metodo average_performance
# 2025-04-04 20:25:09,820 - App_Logger - INFO - Se aplico el metodo percentage_of_active_employees
# 2025-04-04 20:25:09,863 - App_Logger - INFO - Se aplico el metodo average_days_employeed
# 2025-04-04 20:25:09,914 - App_Logger - INFO - Se aplico el metodo count_by_department
# 2025-04-04 20:25:09,917 - App_Logger - INFO - Se aplico el metodo generate_text_report
# reporte.pdf

# %% [markdown]
# ## **Requisitos:**

# %% [markdown]
# 1. **Primera clase: EmployeeDataLoader**
#    - **Constructor**
#      - Debe recibir la lista `empleados` y guardarla en un atributo de instancia.
#    - **Método: get_clean_data()**
#      - Se debe validar que cada diccionario contenga las **trece** claves indicadas (`id`, `nombre`, `edad`, `genero`, `departamento`, `cargo`, `email`, `telefono`, `direccion`, `salario`, `fecha_contratacion`, `desempeno` y `activo`).
#      - Se debe asegurar que `edad` sea entero, `salario` sea flotante, `activo` sea booleano, etc. Si algún valor no cumple con las expectativas, se cataloga como “dato sucio”.
#      - Debe retornar una nueva lista con **solo** los diccionarios válidos y manejar los inválidos de alguna forma.
#
# 2. **Segunda clase: EmployeeAnalyzer**
#    - **Constructor**
#      - Debe recibir la lista resultante de `get_clean_data()` (diccionarios validados).
#    - **Métodos**
#      - `get_average_salary()`:
#        - Calcula el promedio de `salario`.
#      - `count_by_department()`:
#        - Retorna cuántos empleados hay en cada `departamento`.
#      - `average_performance()`:
#        - Calcula el promedio de `desempeno`.
#      - `percentage_of_active_employees()`:
#        - Retorna el porcentaje de empleados con `activo == True`.
#      - `average_days_employed()`:
#        - Calcula el promedio de los días empleados para los empleados activos.
#
# 3. **Tercera clase (con herencia): EmployeeReportGenerator**
# - Esta clase debe **heredar** de `EmployeeAnalyzer`. De esta forma, tendrá acceso directo a los métodos de análisis.
#
# - **Constructor**
#   - Debe recibir la lista validada y enviarla al constructor de la clase padre (`EmployeeAnalyzer`) mediante `super().__init__()`.
#
# - **Método: generate_text_report()**
#   - Debe generar un reporte (en **PDF**) que compile la información calculada por todos los métodos de `EmployeeAnalyzer`.

# %% [markdown]
# ## **Estructura de archivos propuesta**
#
# ```
# my_project/
# ├─ main.py
# ├─ data_loader.py
# ├─ analyzer.py
# └─ report_generator.py
# ```
#
# - **data_loader.py**
#   Contiene la clase `EmployeeDataLoader`.
# - **analyzer.py**
#   Contiene la clase `EmployeeAnalyzer`.
# - **report_generator.py**
#   Contiene la clase `EmployeeReportGenerator`, que hereda de `EmployeeAnalyzer`.
# - **main.py**
#   Actúa como punto de entrada, define la lista `empleados`, instancia las clases y ejecuta el flujo general.

# %% [markdown]
# ## **Pseudo código sugerido**

# %% [markdown]
# #### `main.py`
#
# ``` python
# from data_loader import EmployeeDataLoader
# from report_generator import EmployeeReportGenerator
#
# def main():
#     # Cragar los datos
#     # AQUÍ SE PUEDE CREAR OTRA CLASE!!!
#
#     # Instanciar el cargador y obtener datos limpios
#     loader = EmployeeDataLoader(empleados)
#     clean_data = loader.get_clean_data()
#
#     # Instanciar la clase que hereda de EmployeeAnalyzer (EmployeeReportGenerator)
#     report_generator = EmployeeReportGenerator(clean_data)
#
#     # Generar y mostrar el reporte
#     report = report_generator.generate_text_report()
#     print(report)
#
# if __name__ == "__main__":
#     main()
# ```
# <br>

# %% [markdown]
# #### `employee_data_loader.py`
#
# ``` python
#
# class EmployeeDataLoader:
#     """
#     Clase encargada de recibir y validar la lista de empleados.
#     Verifica que cada diccionario contenga todos los campos requeridos
#     y que dichos campos sean del tipo esperado.
#     """
#
#     def __init__(self, employees):
# ```
# <br>

# %% [markdown]
# ### `employee_analyzer.py`
#
# ``` python
#
# class EmployeeAnalyzer:
#     """
#     Clase enfocada en realizar cálculos y estadísticas
#     a partir de datos de empleados limpios y validados.
#     """
#
#     def __init__(self, employees):
#         """
#         Constructor que recibe la lista de empleados ya validada.
#         """
#         self.employees = employees
# ```
# <br>

# %% [markdown]
# ### `employee_report_generator.py`
#
# ``` python
#
# from employee_analyzer import EmployeeAnalyzer
#
# class EmployeeReportGenerator(EmployeeAnalyzer):
#     """
#     Clase que hereda de EmployeeAnalyzer.
#     Agrega la responsabilidad de generar un reporte textual
#     basado en los cálculos y estadísticas disponibles.
#     """
#
#     def __init__(self, employees):
#         super().__init__(employees)
# ```
